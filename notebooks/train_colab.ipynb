# %% [markdown]
# # Обучение Tri-View 3D Autoencoder
#
# Этот ноутбук предназначен для запуска на **Google Colab (с GPU T4)**.

# %%
# 1. Монтируем Google Drive
from google.colab import drive
import os
drive.mount('/content/drive')

# %%
# 2. Очистка и скачивание актуального кода с GitHub
# Мы удаляем старую папку, чтобы избежать вложенности MultiView_3D_Prediction/MultiView_3D_Prediction
# %cd /content
# !rm -rf MultiView_3D_Prediction
# !git clone https://github.com/3x6dll9ff/MultiView_3D_Prediction.git
# %cd MultiView_3D_Prediction

# %%
# 3. Устанавливаем зависимости
# !pip install -r requirements.txt

# %%
# 4. Распаковываем подготовленные данные
# Мы создаем отдельную папку /content/data, чтобы пути были всегда одинаковыми
# !mkdir -p /content/data
# !unzip -q /content/drive/MyDrive/data_processed.zip -d /content/data

# Проверяем, что файлы на месте
print("Содержимое папки с данными:")
# !ls -F /content/data/processed

# %%
# 5. Запускаем обучение!
# Мы явно указываем путь к данным через --data_dir
# !python3 src/train_reconstruction.py \
    --data_dir /content/data/processed \
    --input_mode tri \
    --epochs 50 \
    --batch_size 16

# %%
# 6. Копируем результат обучения обратно на Google Drive
# !cp -r results /content/drive/MyDrive/MultiView_Results
print("Модель успешно сохранена на Google Drive!")
